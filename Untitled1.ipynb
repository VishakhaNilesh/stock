# %% [markdown]
# <a href="https://colab.research.google.com/github/VishakhaNilesh/stock/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
Response  = requests.get('https://www.cricbuzz.com/cricket-series/9237/indian-premier-league-2025/matches')

# %%
Response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(Response.text,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <script>
#    var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";
#   </script>
#   <style>
# ...

# %%
data=soup.find_all('span')

# %%
for i in soup.find_all('span')
    print(i.text)
# Out:
# Pakistan vs New Zealand
#
# New Zealand vs Pakistan
#
# Rajasthan Royals vs Kolkata Knight Riders
#
# Sunrisers Hyderabad vs Lucknow Super Giants
#
# Chennai Super Kings vs Royal Challengers Bengaluru
#
# Gujarat Titans vs Mumbai Indians
#
# North West vs Titans
#
# Dolphins vs Lions
#
# Western Province vs Boland
#
# Queensland vs South Australia
#   LIVE
# Wellington vs Canterbury
#
# Central Districts vs Auckland
#
# Otago vs Northern Knights
#
#  74 T20s
#  .
# Mar 22
#  - May 25
#  Specials   Wickets Zone Boundary Tracker
#
#  Team  All Kolkata Knight Riders Royal Challengers Bengaluru Sunrisers Hyderabad Rajasthan Royals Mumbai Indians Chennai Super Kings Lucknow Super Giants Delhi Capitals Punjab Kings Gujarat Titans
#
#  Venues    All Kolkata Hyderabad Chennai Visakhapatnam Ahmedabad Guwahati Mumbai Lucknow Bengaluru Chandigarh Jaipur Delhi Dharamsala
#
#
#
# ✖
#
# ✖
#
# ✖
# Date
# Match Details
# Time
#
#
# Kolkata Knight Riders vs Royal Challengers Bengaluru, 1st Match
#
# ...

# %%
tables=pd.read_html(url)

# %%
len(tables)
# Out:
# 11

# %%
df=tables[0]
df.head()
# Out:
#                                                Teams  \
# 0                        Royal Challengers Bengaluru
# 1  OpponentDescriptionDateResultKolkata Knight Ri...
# 2                                           Opponent
# 3                              Kolkata Knight Riders
# 4                                Chennai Super Kings
#
#                                                  Mat  \
# 0                                                  1
# 1  OpponentDescriptionDateResultKolkata Knight Ri...
# 2                                        Description
# 3                                          1st Match
# 4                                          8th Match
#
#                                                  Won  \
# 0                                                  1
# 1  OpponentDescriptionDateResultKolkata Knight Ri...
# 2                                               Date
# 3                                             22 Mar
# ...

# %%
f=tables[10]
df.head(11)
# Out:
#                                                 Teams  \
# 0                         Royal Challengers Bengaluru
# 1   OpponentDescriptionDateResultKolkata Knight Ri...
# 2                                            Opponent
# 3                               Kolkata Knight Riders
# 4                                 Chennai Super Kings
# 5                                      Gujarat Titans
# 6                                      Mumbai Indians
# 7                                      Delhi Capitals
# 8                                    Rajasthan Royals
# 9                                        Punjab Kings
# 10                                       Punjab Kings
#
#                                                   Mat  \
# 0                                                   1
# 1   OpponentDescriptionDateResultKolkata Knight Ri...
# 2                                         Description
# 3                                           1st Match
# ...

# %%
url=requests.get('https://m.cricbuzz.com/cricket-series/9237/indian-premier-league-2025/stats')
url
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(Response.text,'html.parser')

# %%
table=soup.find('th',class_='w-full font-bold capitalize  col-span-2 text-left wb:col-span-3 ')
